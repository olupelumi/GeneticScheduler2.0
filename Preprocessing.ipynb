# %%
import pandas as pd

# %%
surveydf=pd.read_excel('SummerAvailabilityWeek7.xlsx')

# %%
surveydf.head()
# Out:
#                 Name Can you work anytime between (6/24-6/28)?  \
# 0  Elizabeth Hergert                                       Yes
# 1             Alyson                                       Yes
# 2     Adriana Amaris                                       Yes
# 3          sarah gao                                       Yes
# 4      marlena fleck                                       Yes
#
#   What is your ideal number of hours worked at a time (shift length)?  \
# 0                                   2 hours, 3 hours
# 1                                            2 hours
# 2                                            2 hours
# 3                                   2 hours, 3 hours
# 4                                            2 hours
#
#    How many hours would you like to work the first week (6/24-6/28)?  \
# 0                                                 15
# 1                                                 11
# 2                                                 10
# 3                                                  9
# 4                                                 12
#
#    Monday (6/24) [7:30 am - 8:55 am] Monday (6/24) [8:55 am - 9:55 am]  \
# 0  I'd PREFER NOT to work this shift      I'm NEUTRAL about this shift
# 1       I'm NEUTRAL about this shift      I'm NEUTRAL about this shift
# 2                  I WANT this shift                 I WANT this shift
# 3                  I WANT this shift                 I WANT this shift
# 4                  I WANT this shift                 I WANT this shift
#
#   Monday (6/24) [9:55 am - 10:55 am] Monday (6/24) [10:55 am - 11:55 am]  \
# 0                  I WANT this shift                   I WANT this shift
# 1       I'm NEUTRAL about this shift        I'm NEUTRAL about this shift
# 2           I CANNOT work this shift            I CANNOT work this shift
# 3                  I WANT this shift            I CANNOT work this shift
# 4                  I WANT this shift                   I WANT this shift
#
#   Monday (6/24) [11:55 am - 12:55 pm] Monday (6/24) [12:55 pm - 1:55 pm]  ...  \
# 0                   I WANT this shift                  I WANT this shift  ...
# 1        I'm NEUTRAL about this shift       I'm NEUTRAL about this shift  ...
# 2            I CANNOT work this shift           I CANNOT work this shift  ...
# 3            I CANNOT work this shift           I CANNOT work this shift  ...
# 4                   I WANT this shift                  I WANT this shift  ...
#
#    Friday (6/28) [7:30 am - 8:55 am] Friday (6/28) [8:55 am - 9:55 am]  \
# 0  I'd PREFER NOT to work this shift         I WANT to work this shift
# 1       I'm NEUTRAL about this shift      I'm NEUTRAL about this shift
# 2          I WANT to work this shift         I WANT to work this shift
# 3          I WANT to work this shift         I WANT to work this shift
# 4          I WANT to work this shift         I WANT to work this shift
#
#   Friday (6/28) [9:55 am - 10:55 am] Friday (6/28) [10:55 am - 11:55 am]  \
# 0          I WANT to work this shift           I WANT to work this shift
# 1       I'm NEUTRAL about this shift        I'm NEUTRAL about this shift
# 2           I CANNOT work this shift            I CANNOT work this shift
# 3          I WANT to work this shift            I CANNOT work this shift
# 4          I WANT to work this shift           I WANT to work this shift
#
#   Friday (6/28) [11:55 am - 12:55 pm] Friday (6/28) [12:55 pm - 1:55 pm]  \
# 0           I WANT to work this shift          I WANT to work this shift
# 1        I'm NEUTRAL about this shift       I'm NEUTRAL about this shift
# 2            I CANNOT work this shift           I CANNOT work this shift
# 3            I CANNOT work this shift           I CANNOT work this shift
# 4           I WANT to work this shift          I WANT to work this shift
#
#   Friday (6/28) [1:55 pm - 2:55 pm]  Friday (6/28) [2:55 pm - 3:55 pm]  \
# 0         I WANT to work this shift  I'd PREFER NOT to work this shift
# 1      I'm NEUTRAL about this shift       I'm NEUTRAL about this shift
# 2          I CANNOT work this shift           I CANNOT work this shift
# 3          I CANNOT work this shift           I CANNOT work this shift
# 4         I WANT to work this shift          I WANT to work this shift
#
#   Friday (6/28) [3:55 pm - 4:55 pm] Friday (6/28) [4:55 pm - close]
# 0         I WANT to work this shift       I WANT to work this shift
# 1      I'm NEUTRAL about this shift    I'm NEUTRAL about this shift
# 2         I WANT to work this shift       I WANT to work this shift
# 3          I CANNOT work this shift        I CANNOT work this shift
# 4         I WANT to work this shift       I WANT to work this shift
#
# [5 rows x 54 columns]

# %%
#Editing thhe dataframe so worker's preferences can be in terms of numerical categories. 
#The idea is that this will be useful later for computing fitness in the genetic algorithm
surveydf_changed=surveydf.mask(cond = surveydf == "I CANNOT work this shift",other = 1)
surveydf_changed=surveydf_changed.mask(cond = surveydf_changed == "I'd PREFER NOT to work this shift",other = 2)
surveydf_changed=surveydf_changed.mask(cond = surveydf_changed == "I'm NEUTRAL about this shift",other=3)
surveydf_changed=surveydf_changed.mask(cond = surveydf_changed == "I WANT this shift",other = 4)
surveydf_changed=surveydf_changed.mask(cond = surveydf_changed == "I WANT to work this shift",other = 4)
surveydf_changed
# Out:
#                  Name Can you work anytime between (6/24-6/28)?  \
# 0   Elizabeth Hergert                                       Yes
# 1              Alyson                                       Yes
# 2      Adriana Amaris                                       Yes
# 3           sarah gao                                       Yes
# 4       marlena fleck                                       Yes
# 5               Gabby                                       Yes
# 6                nina                                       Yes
# 7         Andrea Doan                                       Yes
# 8              Miguel                                       Yes
# 9          Laura Jabr                                       Yes
# 10               Alex                                       Yes
# 11        Morgan Seay                                       Yes
# 12                Leo                                       Yes
#
#    What is your ideal number of hours worked at a time (shift length)?  \
# 0                                    2 hours, 3 hours
# 1                                             2 hours
# 2                                             2 hours
# 3                                    2 hours, 3 hours
# 4                                             2 hours
# 5                                    3 hours, 4 hours
# 6                                    2 hours, 3 hours
# 7                                    3 hours, 4 hours
# 8                                    2 hours, 3 hours
# 9                                    2 hours, 3 hours
# 10                                            3 hours
# 11                                            2 hours
# 12                                            2 hours
#
#     How many hours would you like to work the first week (6/24-6/28)?  \
# 0                                                  15
# 1                                                  11
# 2                                                  10
# 3                                                   9
# 4                                                  12
# 5                                                  12
# 6                                                  25
# 7                                                  20
# 8                                                  10
# 9                                                  12
# 10                                                 14
# 11                                                  9
# 12                                                  8
#
#    Monday (6/24) [7:30 am - 8:55 am] Monday (6/24) [8:55 am - 9:55 am]  \
# 0                                  2                                 3
# 1                                  3                                 3
# 2                                  4                                 4
# 3                                  4                                 4
# 4                                  4                                 4
# 5                                  3                                 3
# 6                                  2                                 2
# 7                                  1                                 1
# 8                                  2                                 2
# 9                                  2                                 4
# 10                                 2                                 2
# 11                                 2                                 4
# 12                                 1                                 1
#
#    Monday (6/24) [9:55 am - 10:55 am] Monday (6/24) [10:55 am - 11:55 am]  \
# 0                                   4                                   4
# 1                                   3                                   3
# 2                                   1                                   1
# 3                                   4                                   1
# 4                                   4                                   4
# 5                                   3                                   3
# 6                                   3                                   3
# 7                                   1                                   1
# 8                                   3                                   3
# 9                                   1                                   1
# 10                                  4                                   4
# 11                                  4                                   2
# 12                                  1                                   4
#
#    Monday (6/24) [11:55 am - 12:55 pm] Monday (6/24) [12:55 pm - 1:55 pm]  \
# 0                                    4                                  4
# 1                                    3                                  3
# 2                                    1                                  1
# 3                                    1                                  1
# 4                                    4                                  4
# 5                                    3                                  3
# 6                                    4                                  4
# 7                                    1                                  3
# 8                                    4                                  4
# 9                                    1                                  1
# 10                                   4                                  1
# 11                                   3                                  1
# 12                                   4                                  2
#
#     ... Friday (6/28) [7:30 am - 8:55 am] Friday (6/28) [8:55 am - 9:55 am]  \
# 0   ...                                 2                                 4
# 1   ...                                 3                                 3
# 2   ...                                 4                                 4
# 3   ...                                 4                                 4
# 4   ...                                 4                                 4
# 5   ...                                 3                                 3
# 6   ...                                 2                                 2
# 7   ...                                 1                                 1
# 8   ...                                 2                                 2
# 9   ...                                 2                                 4
# 10  ...                                 2                                 2
# 11  ...                                 1                                 1
# 12  ...                                 1                                 1
#
#    Friday (6/28) [9:55 am - 10:55 am] Friday (6/28) [10:55 am - 11:55 am]  \
# 0                                   4                                   4
# 1                                   3                                   3
# 2                                   1                                   1
# 3                                   4                                   1
# 4                                   4                                   4
# 5                                   3                                   3
# 6                                   3                                   3
# 7                                   1                                   1
# 8                                   4                                   4
# 9                                   4                                   4
# 10                                  4                                   4
# 11                                  1                                   1
# 12                                  1                                   4
#
#    Friday (6/28) [11:55 am - 12:55 pm] Friday (6/28) [12:55 pm - 1:55 pm]  \
# 0                                    4                                  4
# 1                                    3                                  3
# 2                                    1                                  1
# 3                                    1                                  1
# 4                                    4                                  4
# 5                                    3                                  3
# 6                                    4                                  4
# 7                                    1                                  3
# 8                                    4                                  4
# 9                                    4                                  4
# 10                                   4                                  3
# 11                                   1                                  4
# 12                                   4                                  3
#
#    Friday (6/28) [1:55 pm - 2:55 pm] Friday (6/28) [2:55 pm - 3:55 pm]  \
# 0                                  4                                 2
# 1                                  3                                 3
# 2                                  1                                 1
# 3                                  1                                 1
# 4                                  4                                 4
# 5                                  3                                 3
# 6                                  3                                 3
# 7                                  4                                 4
# 8                                  4                                 4
# 9                                  3                                 4
# 10                                 3                                 3
# 11                                 4                                 3
# 12                                 3                                 3
#
#    Friday (6/28) [3:55 pm - 4:55 pm] Friday (6/28) [4:55 pm - close]
# 0                                  4                               4
# 1                                  3                               3
# 2                                  4                               4
# 3                                  1                               1
# 4                                  4                               4
# 5                                  3                               1
# 6                                  3                               3
# 7                                  4                               4
# 8                                  2                               2
# 9                                  4                               3
# 10                                 3                               3
# 11                                 4                               4
# 12                                 4                               4
#
# [13 rows x 54 columns]
